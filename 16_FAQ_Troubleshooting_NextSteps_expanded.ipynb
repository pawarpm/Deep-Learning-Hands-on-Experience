# %% [markdown]
# # Module 16 — FAQ, Troubleshooting & Next Steps (Expanded)\n\nGenerated expanded notebook.

# %% [markdown]
# # Module 16 — FAQ, Troubleshooting & Next Steps (Expanded)
#
# This notebook collects common issues, troubleshooting steps, and suggestions to scale the curriculum or explore next topics.

# %% [markdown]
# ## 1 — Common Colab issues and fixes

# %%
# GPU not available: check Runtime > Change runtime type > Hardware accelerator = GPU
# Package conflict: pin versions in first cell, or create a fresh Colab notebook
print('Common issues checklist (see markdown)')

# %% [markdown]
# ## 2 — Performance tips

# %% [markdown]
# - Reduce batch size and image size for limited GPU memory
# - Use smaller backbones like MobileNet for faster demos
# - Freeze pretrained layers during in-class demos to save time

# %% [markdown]
# ## 3 — Scaling the curriculum
#
# Electives to add:
# - GANs and image-to-image translation
# - Reinforcement learning basics
# - Privacy-preserving ML (federated learning, differential privacy)
# - Advanced CV (self-supervised learning, DETR, Segment Anything)

# %% [markdown]
# ## 4 — Assessment & delivering feedback
#
# - Provide a reproducibility checklist to students
# - Encourage short writeups explaining mistakes and lessons learned
# - Use automated tests (unit tests) for grading code submissions where practical

# %% [markdown]
# ## 5 — Links & resources
#
# - Papers: ResNet, UNet, Transformer (Vaswani et al.)
# - Tooling: Roboflow, Weights & Biases, Hugging Face
# - Datasets: CIFAR-10, ImageNet (subset), Oxford Flowers, ESC-50
